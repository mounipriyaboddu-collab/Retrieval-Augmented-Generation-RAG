# %% [markdown]
# <a href="https://colab.research.google.com/github/mounipriyaboddu-collab/Team4-SLM-Learning-journey/blob/main/DAY_3_PYTHON_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multiplication_table(num):
    for i in range(1, 11):
        print(f"{num} x {i} = {num * i}")

number = int(input("Enter a number: "))
multiplication_table(number)
# Out:
# Enter a number: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
data_store = []

data_store.append("Python")
data_store.append("Java")
data_store.append("C")

print("Stored Data:", data_store)
# Out:
# Stored Data: ['Python', 'Java', 'C']

# %%
students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")
    students.append(name)

print("Student List:", students)
# Out:
# Enter number of students: 4
# Enter student name: mouni priya
# Enter student name: priyadarashini
# Enter student name: surya
# Enter student name: siri
# Student List: ['mouni priya', 'priyadarashini', 'surya', 'siri']

# %%
students = ["siri", "mouni", "surya", "Priya"]

print("Student Names:")
for student in students:
    print(student)
# Out:
# Student Names:
# siri
# mouni
# surya
# Priya

# %%
def add_numbers(a, b):
    return a + b

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = add_numbers(num1, num2)
print("Sum =", result)
# Out:
# Enter first number: 27
# Enter second number: 68
# Sum = 95

# %%
def display_student(name, roll_no, course):
    print("Student Details")
    print("Name:", name)
    print("Roll No:", roll_no)
    print("Course:", course)

display_student("mouni priya", 4214, "python")
# Out:
# Student Details
# Name: mouni priya
# Roll No: 4214
# Course: python
